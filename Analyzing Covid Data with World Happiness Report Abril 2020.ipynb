# %% [markdown]
# # Importing Important Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from IPython.display import display

print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# # Importing covid19 dataset

# %%
corona_dataset_csv = pd.read_csv('time_series_covid19_confirmed_global.csv')
display(corona_dataset_csv.head(10))
print("shape:", corona_dataset_csv.shape)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  7/17/20  \
# 0        0        0        0        0        0        0  ...    35229
# 1        0        0        0        0        0        0  ...     3906
# 2        0        0        0        0        0        0  ...    21948
# 3        0        0        0        0        0        0  ...      880
# 4        0        0        0        0        0        0  ...      638
# 5        0        0        0        0        0        0  ...       76
# 6        0        0        0        0        0        0  ...   119301
# 7        0        0        0        0        0        0  ...    34001
# 8        0        0        0        0        0        0  ...      113
# 9        0        0        0        0        3        4  ...     3550
#
#    7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20  7/25/20  \
# 0    35301    35475    35526    35615    35727    35928    35981    36036
# 1     4008     4090     4171     4290     4358     4466     4570     4637
# 2    22549    23084    23691    24278    24872    25484    26159    26764
# 3      880      880      884      884      889      889      897      897
# 4      687      705      749      779      812      851      880      916
# 5       76       76       76       76       76       76       82       82
# 6   122524   126755   130774   136118   141900   148027   153520   158334
# 7    34462    34877    34981    35254    35693    36162    36613    36996
# 8      113      113      113      113      113      113      113      113
# 9     3568     3588     3599     3614     3633     3640     3654     3668
#
#    7/26/20
# 0    36157
# 1     4763
# 2    27357
# 3      897
# 4      932
# 5       82
# 6   162526
# 7    37317
# 8      113
# 9     3685
#
# [10 rows x 191 columns]
# shape: (266, 191)

# %% [markdown]
# ## Deleting useless columns

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  7/17/20  \
# 0        0        0        0        0        0        0  ...    35229
# 1        0        0        0        0        0        0  ...     3906
# 2        0        0        0        0        0        0  ...    21948
# 3        0        0        0        0        0        0  ...      880
# 4        0        0        0        0        0        0  ...      638
# 5        0        0        0        0        0        0  ...       76
# 6        0        0        0        0        0        0  ...   119301
# 7        0        0        0        0        0        0  ...    34001
# 8        0        0        0        0        0        0  ...      113
# 9        0        0        3        4        4        4  ...     3550
#
#    7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  7/24/20  7/25/20  \
# 0    35301    35475    35526    35615    35727    35928    35981    36036
# 1     4008     4090     4171     4290     4358     4466     4570     4637
# 2    22549    23084    23691    24278    24872    25484    26159    26764
# 3      880      880      884      884      889      889      897      897
# 4      687      705      749      779      812      851      880      916
# 5       76       76       76       76       76       76       82       82
# 6   122524   126755   130774   136118   141900   148027   153520   158334
# 7    34462    34877    34981    35254    35693    36162    36613    36996
# 8      113      113      113      113      113      113      113      113
# 9     3568     3588     3599     3614     3633     3640     3654     3668
#
#    7/26/20
# 0    36157
# 1     4763
# 2    27357
# 3      897
# 4      932
# 5       82
# 6   162526
# 7    37317
# 8      113
# 9     3685
#
# [10 rows x 189 columns]

# %% [markdown]
#  # Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  7/17/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...    35229
# Albania                    0        0        0        0  ...     3906
# Algeria                    0        0        0        0  ...    21948
# Andorra                    0        0        0        0  ...      880
# Angola                     0        0        0        0  ...      638
# Antigua and Barbuda        0        0        0        0  ...       76
# Argentina                  0        0        0        0  ...   119301
# Armenia                    0        0        0        0  ...    34001
# Australia                  5        6        9        9  ...    11441
# Austria                    0        0        0        0  ...    19439
#
#                      7/18/20  7/19/20  7/20/20  7/21/20  7/22/20  7/23/20  \
# Country/Region
# Afghanistan            35301    35475    35526    35615    35727    35928
# Albania                 4008     4090     4171     4290     4358     4466
# Algeria                22549    23084    23691    24278    24872    25484
# Andorra                  880      880      884      884      889      889
# Angola                   687      705      749      779      812      851
# Antigua and Barbuda       76       76       76       76       76       76
# Argentina             122524   126755   130774   136118   141900   148027
# Armenia                34462    34877    34981    35254    35693    36162
# Australia              11802    12069    12428    12894    13302    13595
# Austria                19573    19655    19743    19827    19929    20099
#
#                      7/24/20  7/25/20  7/26/20
# Country/Region
# Afghanistan            35981    36036    36157
# Albania                 4570     4637     4763
# Algeria                26159    26764    27357
# Andorra                  897      897      897
# Angola                   880      916      932
# Antigua and Barbuda       82       82       82
# Argentina             153520   158334   162526
# Armenia                36613    36996    37317
# Australia              13950    14403    14935
# Austria                20214    20338    20472
#
# [10 rows x 187 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (188, 187)

# %% [markdown]
# ## Visualizing data related to a country for example China

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
corona_dataset_aggregated.loc['India'].plot()
plt.legend()

# %% [markdown]
# ##  Caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['India'].diff().plot()
corona_dataset_aggregated.loc['China'].diff().plot()
plt.legend()

# %% [markdown]
# ## Find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 49981.0

# %% [markdown]
# ## Find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  7/18/20  7/19/20  7/20/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    35301    35475    35526
# Albania               0        0        0  ...     4008     4090     4171
# Algeria               0        0        0  ...    22549    23084    23691
# Andorra               0        0        0  ...      880      880      884
# Angola                0        0        0  ...      687      705      749
#
#                 7/21/20  7/22/20  7/23/20  7/24/20  7/25/20  7/26/20  \
# Country/Region
# Afghanistan       35615    35727    35928    35981    36036    36157
# Albania            4290     4358     4466     4570     4637     4763
# Algeria           24278    24872    25484    26159    26764    27357
# Andorra             884      889      889      897      897      897
# Angola              779      812      851      880      916      932
#
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      126.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                        62.0
#
# [5 rows x 188 columns]

# %% [markdown]
# # Create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      126.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                        62.0

# %% [markdown]
# ## Importing the world happiness report

# %%
world_happiness_report = pd.read_csv("worldwide_happiness_report.csv")
world_happiness_report.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# ## Dropping useless Columns

# %%
columns_to_drop = ['Overall rank','Score','Generosity','Perceptions of corruption']
world_happiness_report.drop(columns_to_drop,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ## Changing the indices of the dataframe

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)
world_happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ## Joining the two datasets

# %%
data = world_happiness_report.join(corona_data,how="inner")
data.head()
# Out:
#              GDP per capita  Social support  Healthy life expectancy  \
# Finland               1.340           1.587                    0.986
# Denmark               1.383           1.573                    0.996
# Norway                1.488           1.582                    1.028
# Iceland               1.380           1.624                    1.026
# Netherlands           1.396           1.522                    0.999
#
#              Freedom to make life choices  max infection rate
# Finland                             0.596               267.0
# Denmark                             0.592               391.0
# Norway                              0.603               386.0
# Iceland                             0.591                99.0
# Netherlands                         0.557              1346.0

# %% [markdown]
# ## Correlation Matrix

# %%
data.corr()
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.757521
# Social support                      0.757521        1.000000
# Healthy life expectancy             0.859431        0.751632
# Freedom to make life choices        0.394799        0.456317
# max infection rate                  0.113979        0.089225
#
#                               Healthy life expectancy  \
# GDP per capita                               0.859431
# Social support                               0.751632
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.423146
# max infection rate                           0.098597
#
#                               Freedom to make life choices  max infection rate
# GDP per capita                                    0.394799            0.113979
# Social support                                    0.456317            0.089225
# Healthy life expectancy                           0.423146            0.098597
# Freedom to make life choices                      1.000000            0.078378
# max infection rate                                0.078378            1.000000

# %% [markdown]
# # Visualization of the results Globally

# %% [markdown]
# ## Plotting GDP vs maximum Infection rate

# %%
x = data['GDP per capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ## Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# # Visualization of the results for India

# %%
inverse_data = data.transpose()

# %%
inverse_data.head()
# Out:
#                               Finland  Denmark   Norway  Iceland  Netherlands  \
# GDP per capita                  1.340    1.383    1.488    1.380        1.396
# Social support                  1.587    1.573    1.582    1.624        1.522
# Healthy life expectancy         0.986    0.996    1.028    1.026        0.999
# Freedom to make life choices    0.596    0.592    0.603    0.591        0.557
# max infection rate            267.000  391.000  386.000   99.000     1346.000
#
#                               Switzerland    Sweden  New Zealand    Canada  \
# GDP per capita                      1.452     1.387        1.303     1.365
# Social support                      1.526     1.487        1.557     1.505
# Healthy life expectancy             1.052     1.009        1.026     1.039
# Freedom to make life choices        0.572     0.574        0.585     0.584
# max infection rate               1321.000  2530.000       89.000  2778.000
#
#                                Austria  ...    Haiti  Botswana   Syria  \
# GDP per capita                   1.376  ...    0.323     1.041   0.619
# Social support                   1.475  ...    0.688     1.145   0.378
# Healthy life expectancy          1.016  ...    0.449     0.538   0.440
# Freedom to make life choices     0.532  ...    0.026     0.455   0.013
# max infection rate            1321.000  ...  332.000   123.000  26.000
#
#                                Malawi    Yemen   Rwanda  Tanzania  \
# GDP per capita                  0.191    0.287    0.359     0.476
# Social support                  0.560    1.163    0.711     0.885
# Healthy life expectancy         0.495    0.463    0.614     0.499
# Freedom to make life choices    0.443    0.143    0.555     0.417
# max infection rate            257.000  116.000  101.000   181.000
#
#                               Afghanistan  Central African Republic  \
# GDP per capita                      0.350                     0.026
# Social support                      0.517                     0.000
# Healthy life expectancy             0.361                     0.105
# Freedom to make life choices        0.000                     0.225
# max infection rate                915.000                   216.000
#
#                               South Sudan
# GDP per capita                      0.306
# Social support                      0.575
# Healthy life expectancy             0.295
# Freedom to make life choices        0.010
# max infection rate                323.000
#
# [5 rows x 144 columns]

# %%
india_data = inverse_data.India
df = pd.DataFrame(india_data) 
df
# Out:
#                                   India
# GDP per capita                    0.755
# Social support                    0.765
# Healthy life expectancy           0.588
# Freedom to make life choices      0.498
# max infection rate            49981.000

# %% [markdown]
# ## Results for Mexico

# %%
inverse_data.Mexico
# Out:
# GDP per capita                     1.070
# Social support                     1.323
# Healthy life expectancy            0.861
# Freedom to make life choices       0.433
# max infection rate              8438.000
# Name: Mexico, dtype: float64

# %%
corona_dataset_aggregated.loc['Mexico'].plot()

# %% [markdown]
# ### First derivate for Mexico's number of infections

# %%
corona_dataset_aggregated.loc['Mexico'].diff().plot()
plt.legend()
